# %% [markdown]
# # Interactive Turing Machine Visualization
#
# This notebook demonstrates the interactive visualization of Turing Machines.

# %%
from busy_beaver_blaze import Visualizer, BB5_CHAMP, BB6_CONTENDER  # noqa: F401

# %% [markdown]
# ## Example: BB5 Champion with Early Stop
#
# Run the BB5 champion machine up to 10_000,000 steps with live updates.

# %%
# Create visualizer (defaults to 800x600 and colorful palette)
machine = Visualizer(
    program=BB5_CHAMP
)

# Visualize with early stop
machine.run_live(
    early_stop=10_000_000,
    caption="BB5 Champion"
)
# Out:
# Step 10,000,000 | Nonblanks: 5,005 | BB5 Champion
# ✓ Reached early_stop at step 10,000,000

# %% [markdown]
# ## Example: Indefinite Running (Stop with Ctrl+C)
#
# Run without an early_stop limit. Use the stop button or Ctrl+C to interrupt.

# %%
# Create fresh visualizer (uses defaults)
machine = Visualizer(
    program=BB5_CHAMP
)

# Run indefinitely - click 'Interrupt' button or press Ctrl+C to halt
machine.run_live(
    caption="BB5 - Click 'Interrupt' to Halt"
)
# Out:
# Step 7,920,000 | Nonblanks: 3,885 | BB5 - Click 'Interrupt' to Halt
# ⏹ Stopped by user at step 7,920,000

# %% [markdown]
# ## Example: Custom Colors
#
# Create a machine with custom color palette.

# %%
# Create visualizer with custom colors
machine = Visualizer(
    program=BB5_CHAMP,
    colors=["#FFFFFF", "#FF5500", "#FFFF00", "#FF00FF", "#00FFFF"]  # White, orange, yellow, magenta, cyan
)

machine.run_live(
    early_stop=50_000,
    caption="BB5 with Custom Colors"
)
# Out:
# Step 50,000 | Nonblanks: 329 | BB5 with Custom Colors
# ✓ Reached early_stop at step 50,000

# %% [markdown]
# ## Example: User-defined Program (BB6 Contender)
#
# You can create your own Turing machine programs using any of the common string formats. For example, BB6 Contender program:
#
# ```text
# 	A	B	C	D	E	F
# 0	1RB	1RC	1LC	0LE	1LF	0RC
# 1	0LD	0RF	1LA	1RH	0RB	0RE
# ```
#
# You can pass either the built-in `BB6_CONTENDER` constant or the string literal above.

# %%
from pathlib import Path
import tempfile
from busy_beaver_blaze import Visualizer

out_file = Path(tempfile.gettempdir()) / "busy_beaver_blaze_images" / "bb6_200K.png"

# Create and step the machine to a point of interest
machine = Visualizer(
    program="""
        A\tB\tC\tD\tE\tF
0\t1RB\t1RC\t1LC\t0LE\t1LF\t0RC
1\t0LD\t0RF\t1LA\t1RH\t0RB\t0RE
"""
)
# Render the frame and optionally save it to disk
img, step_count = machine.run(early_stop=200_000, out_file=out_file)

# Display the image in the notebook
display(img)
print(f"Captured step count: {step_count:,}")
print(f"Saved to: {out_file}")
# Out:
# Step count: 200,000
# <PIL.Image.Image image mode=RGBA size=800x600>
# Captured step count: 200,000
# Saved to: C:\Users\carlk\AppData\Local\Temp\busy_beaver_blaze_images\bb6_200K.png

# %%
from pathlib import Path
import tempfile
from busy_beaver_blaze import Visualizer, BB5_CHAMP

machine = Visualizer(
    program=BB5_CHAMP,
    resolution=(1920, 1080)
)

out_file = Path(tempfile.gettempdir()) / "busy_beaver_blaze_images" / "bb5_champ.png"
img, step_count = machine.run(out_file=out_file, early_stop=100_000_000)
print(f"Step count: {step_count:,}, Saved to: {out_file}")
img
# Out:
# Step count: 47,176,870
# Step count: 47,176,870, Saved to: C:\Users\carlk\AppData\Local\Temp\busy_beaver_blaze_images\bb5_champ.png
# <PIL.Image.Image image mode=RGBA size=1920x1080>
