# %%
# infinite loop in python (after a while, press the Interrupt button to stop)
while True:
    pass
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 # infinite loop in python (after a while, press the Interrupt button to stop)
# ----> 2 while True:
#       3     pass
#
# KeyboardInterrupt:

# %%
# (after a while, press the Interrupt button to stop)
for a in range(10**100):
    for b in range(10**100):
        if b % 10_000_000 == 0:
            print(f"{a:,}, {b:,}")
# Out:
# 0, 0
# 0, 10,000,000
# 0, 20,000,000
# 0, 30,000,000
# 0, 40,000,000
# 0, 50,000,000
# 0, 60,000,000
# 0, 70,000,000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 for a in range(10**100):
#       2     for b in range(10**100):
# ----> 3         if b % 10_000_000 == 0:
#       4             print(f"{a:,}, {b:,}")
#
# KeyboardInterrupt:

# %%
from sys import getsizeof

print(f"{getsizeof(10**100)} bytes")
# Out:
# 72 bytes
